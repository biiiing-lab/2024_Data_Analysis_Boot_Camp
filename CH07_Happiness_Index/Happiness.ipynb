# %%
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.font_manager as fm
from pandas import *

# %%
# 한글 폰트 경로 설정 (예: 나눔고딕)
font_path = "C:/Windows/Fonts/NanumGothic.ttf"
font_prop = fm.FontProperties(fname=font_path)
plt.rcParams['font.family'] = font_prop.get_name()

# %%
happy_life = read_excel('./file/대한민국행복지도_삶의만족도.xlsx')
happy_health = read_excel('./file/대한민국행복지도_건강.xlsx')
happy_safe = read_excel('./file/대한민국행복지도_안전.xlsx')
happy_environ = read_excel('./file/대한민국행복지도_환경.xlsx')
happy_econo = read_excel('./file/대한민국행복지도_경제.xlsx')
happy_edu = read_excel('./file/대한민국행복지도_교육.xlsx')
happy_relation = read_excel('./file/대한민국행복지도_관계및사회참여.xlsx')
happy_leisure = read_excel('./file/대한민국행복지도_여가.xlsx')

# %%
# '시', '도' 데이터 추출
city = list(happy_life['시도'].unique())
happy_merge=DataFrame({
    '시도' : city
})
happy_merge
# Out:
#          시도
# 0     서울특별시
# 1     부산광역시
# 2     대구광역시
# 3     인천광역시
# 4     광주광역시
# 5     대전광역시
# 6     울산광역시
# 7   세종특별자치시
# 8       경기도
# 9       강원도
# 10     충청북도
# 11     충청남도
# 12     전라북도
# 13     전라남도
# 14     경상북도
# 15     경상남도
# 16  제주특별자치도

# %%
# '삶의 만족도' 데이터 병합
life = happy_life['삶의 만족도'].groupby(by=happy_life['시도']).mean()
happy_merge = merge(happy_merge, life, on ='시도')
happy_merge
# Out:
#          시도  삶의 만족도_x  삶의 만족도_y    삶의 만족도
# 0     서울특별시  0.490972  0.490972  0.490972
# 1     부산광역시  0.362081  0.362081  0.362081
# 2     대구광역시  0.363988  0.363988  0.363988
# 3     인천광역시  0.411480  0.411480  0.411480
# 4     광주광역시  0.484480  0.484480  0.484480
# 5     대전광역시  0.407580  0.407580  0.407580
# 6     울산광역시  0.471980  0.471980  0.471980
# 7   세종특별자치시  0.907700  0.907700  0.907700
# 8       경기도  0.426023  0.426023  0.426023
# 9       강원도  0.619506  0.619506  0.619506
# 10     충청북도  0.410100  0.410100  0.410100
# 11     충청남도  0.553100  0.553100  0.553100
# 12     전라북도  0.608193  0.608193  0.608193
# 13     전라남도  0.547709  0.547709  0.547709
# 14     경상북도  0.502223  0.502223  0.502223
# 15     경상남도  0.530794  0.530794  0.530794
# 16  제주특별자치도  0.711300  0.711300  0.711300

# %%
health = happy_health['평균'].groupby(by=happy_health['시도']).mean() # 시도별 건강 평균
happy_merge = merge(happy_merge, health.rename('건강'), on='시도') # 시도별 건강 평균을 happy_merge에 추가
happy_merge.head()
# Out:
#       시도  삶의 만족도_x  삶의 만족도_y    삶의 만족도        건강
# 0  서울특별시  0.490972  0.490972  0.490972  0.569532
# 1  부산광역시  0.362081  0.362081  0.362081  0.511906
# 2  대구광역시  0.363988  0.363988  0.363988  0.482325
# 3  인천광역시  0.411480  0.411480  0.411480  0.339620
# 4  광주광역시  0.484480  0.484480  0.484480  0.632300

# %%
safe = happy_safe['평균'].groupby(by=happy_safe['시도']).mean()
happy_merge = merge(happy_merge, safe.rename('안전'), on='시도')
happy_merge.head()
# Out:
#       시도  삶의 만족도_x  삶의 만족도_y    삶의 만족도        건강        안전
# 0  서울특별시  0.490972  0.490972  0.490972  0.569532  0.552256
# 1  부산광역시  0.362081  0.362081  0.362081  0.511906  0.404875
# 2  대구광역시  0.363988  0.363988  0.363988  0.482325  0.358429
# 3  인천광역시  0.411480  0.411480  0.411480  0.339620  0.421020
# 4  광주광역시  0.484480  0.484480  0.484480  0.632300  0.266440

# %%
environ = happy_environ['평균'].groupby(by=happy_environ['시도']).mean()
happy_merge = merge(happy_merge, environ.rename('환경'), on='시도')
happy_merge.head()
# Out:
#       시도  삶의 만족도_x  삶의 만족도_y    삶의 만족도        건강        안전        환경
# 0  서울특별시  0.490972  0.490972  0.490972  0.569532  0.552256  0.470712
# 1  부산광역시  0.362081  0.362081  0.362081  0.511906  0.404875  0.448719
# 2  대구광역시  0.363988  0.363988  0.363988  0.482325  0.358429  0.552500
# 3  인천광역시  0.411480  0.411480  0.411480  0.339620  0.421020  0.515020
# 4  광주광역시  0.484480  0.484480  0.484480  0.632300  0.266440  0.607480

# %%
econo = happy_econo['평균'].groupby(by=happy_econo['시도']).mean()
happy_merge = merge(happy_merge, econo.rename('경제'), on='시도')
happy_merge.head()
# Out:
#       시도  삶의 만족도_x  삶의 만족도_y    삶의 만족도        건강        안전        환경        경제
# 0  서울특별시  0.490972  0.490972  0.490972  0.569532  0.552256  0.470712  0.532820
# 1  부산광역시  0.362081  0.362081  0.362081  0.511906  0.404875  0.448719  0.438038
# 2  대구광역시  0.363988  0.363988  0.363988  0.482325  0.358429  0.552500  0.393975
# 3  인천광역시  0.411480  0.411480  0.411480  0.339620  0.421020  0.515020  0.410820
# 4  광주광역시  0.484480  0.484480  0.484480  0.632300  0.266440  0.607480  0.387380

# %%
edu = happy_edu['평균'].groupby(by=happy_edu['시도']).mean()
happy_merge = merge(happy_merge, edu.rename('교육'), on='시도')
happy_merge.head()
# Out:
#       시도  삶의 만족도_x  삶의 만족도_y    삶의 만족도        건강        안전        환경  \
# 0  서울특별시  0.490972  0.490972  0.490972  0.569532  0.552256  0.470712
# 1  부산광역시  0.362081  0.362081  0.362081  0.511906  0.404875  0.448719
# 2  대구광역시  0.363988  0.363988  0.363988  0.482325  0.358429  0.552500
# 3  인천광역시  0.411480  0.411480  0.411480  0.339620  0.421020  0.515020
# 4  광주광역시  0.484480  0.484480  0.484480  0.632300  0.266440  0.607480
#
#          경제        교육
# 0  0.532820  0.399412
# 1  0.438038  0.504594
# 2  0.393975  0.585838
# 3  0.410820  0.502920
# 4  0.387380  0.689680

# %%
relation = happy_relation['평균'].groupby(by=happy_relation['시도']).mean()
happy_merge = merge(happy_merge, relation.rename('관계및사회참여'), on='시도')
happy_merge.head()
# Out:
#       시도  삶의 만족도_x  삶의 만족도_y    삶의 만족도        건강        안전        환경  \
# 0  서울특별시  0.490972  0.490972  0.490972  0.569532  0.552256  0.470712
# 1  부산광역시  0.362081  0.362081  0.362081  0.511906  0.404875  0.448719
# 2  대구광역시  0.363988  0.363988  0.363988  0.482325  0.358429  0.552500
# 3  인천광역시  0.411480  0.411480  0.411480  0.339620  0.421020  0.515020
# 4  광주광역시  0.484480  0.484480  0.484480  0.632300  0.266440  0.607480
#
#          경제        교육   관계및사회참여
# 0  0.532820  0.399412  0.390656
# 1  0.438038  0.504594  0.294719
# 2  0.393975  0.585838  0.407486
# 3  0.410820  0.502920  0.504920
# 4  0.387380  0.689680  0.637800

# %%
leisure = happy_leisure['평균'].groupby(by=happy_leisure['시도']).mean()
happy_merge = merge(happy_merge, leisure.rename('여가'), on='시도')
happy_merge.head()
# Out:
#       시도  삶의 만족도_x  삶의 만족도_y    삶의 만족도        건강        안전        환경  \
# 0  서울특별시  0.490972  0.490972  0.490972  0.569532  0.552256  0.470712
# 1  부산광역시  0.362081  0.362081  0.362081  0.511906  0.404875  0.448719
# 2  대구광역시  0.363988  0.363988  0.363988  0.482325  0.358429  0.552500
# 3  인천광역시  0.411480  0.411480  0.411480  0.339620  0.421020  0.515020
# 4  광주광역시  0.484480  0.484480  0.484480  0.632300  0.266440  0.607480
#
#          경제        교육   관계및사회참여        여가
# 0  0.532820  0.399412  0.390656  0.286732
# 1  0.438038  0.504594  0.294719  0.153587
# 2  0.393975  0.585838  0.407486  0.234925
# 3  0.410820  0.502920  0.504920  0.244590
# 4  0.387380  0.689680  0.637800  0.454980

# %%
# 데이터 검산
happy_merge.isnull().sum()
# Out:
# 시도          0
# 삶의 만족도_x    0
# 삶의 만족도_y    0
# 삶의 만족도      0
# 건강          0
# 안전          0
# 환경          0
# 경제          0
# 교육          0
# 관계및사회참여     0
# 여가          0
# dtype: int64

# %%
print(happy_merge['건강'].mean())
print(happy_health['평균'].mean())
# Out:
# 0.4094014744072605
# 0.40443508771929826

# %%
happy_merge.describe()
# Out:
#         삶의 만족도_x   삶의 만족도_y     삶의 만족도         건강         안전         환경  \
# count  17.000000  17.000000  17.000000  17.000000  17.000000  17.000000
# mean    0.518189   0.518189   0.518189   0.409401   0.420882   0.579406
# std     0.138257   0.138257   0.138257   0.127636   0.123557   0.097299
# min     0.362081   0.362081   0.362081   0.232000   0.157800   0.393440
# 25%     0.411480   0.411480   0.411480   0.329506   0.358429   0.515020
# 50%     0.490972   0.490972   0.490972   0.401064   0.446100   0.582380
# 75%     0.553100   0.553100   0.553100   0.482325   0.484835   0.652400
# max     0.907700   0.907700   0.907700   0.663580   0.573155   0.735600
#
#               경제         교육    관계및사회참여         여가
# count  17.000000  17.000000  17.000000  17.000000
# mean    0.407635   0.578653   0.497632   0.464910
# std     0.111265   0.125408   0.114394   0.176206
# min     0.196543   0.399412   0.294719   0.153587
# 25%     0.386861   0.488533   0.402183   0.347960
# 50%     0.410820   0.587000   0.487464   0.454980
# 75%     0.468926   0.648047   0.601532   0.632750
# max     0.642580   0.840780   0.676440   0.702891

# %%
happy_merge.mean(axis=0, numeric_only=True)
# 시, 도 컬럼은 텍스트이기 떄문에 평균 계산 시 오류 발생
# Out:
# 삶의 만족도_x    0.518189
# 삶의 만족도_y    0.518189
# 삶의 만족도      0.518189
# 건강          0.409401
# 안전          0.420882
# 환경          0.579406
# 경제          0.407635
# 교육          0.578653
# 관계및사회참여     0.497632
# 여가          0.464910
# dtype: float64

# %%
happy_merge.mean(axis=1, numeric_only=True)
# Out:
# 0     0.467504
# 1     0.384268
# 2     0.410744
# 3     0.417335
# 4     0.512950
# 5     0.479130
# 6     0.520716
# 7     0.598570
# 8     0.463189
# 9     0.544713
# 10    0.482340
# 11    0.517123
# 12    0.512622
# 13    0.509631
# 14    0.449448
# 15    0.492443
# 16    0.589520
# dtype: float64

# %%
happy_merge.set_index('시도').mean(axis=1)
# Out:
# 시도
# 서울특별시      0.467504
# 부산광역시      0.384268
# 대구광역시      0.410744
# 인천광역시      0.417335
# 광주광역시      0.512950
# 대전광역시      0.479130
# 울산광역시      0.520716
# 세종특별자치시    0.598570
# 경기도        0.463189
# 강원도        0.544713
# 충청북도       0.482340
# 충청남도       0.517123
# 전라북도       0.512622
# 전라남도       0.509631
# 경상북도       0.449448
# 경상남도       0.492443
# 제주특별자치도    0.589520
# dtype: float64

# %%
happy_merge.corr(numeric_only=True)
# Out:
#           삶의 만족도_x  삶의 만족도_y    삶의 만족도        건강        안전        환경  \
# 삶의 만족도_x  1.000000  1.000000  1.000000 -0.570466 -0.191709  0.572262
# 삶의 만족도_y  1.000000  1.000000  1.000000 -0.570466 -0.191709  0.572262
# 삶의 만족도    1.000000  1.000000  1.000000 -0.570466 -0.191709  0.572262
# 건강       -0.570466 -0.570466 -0.570466  1.000000 -0.210138 -0.357841
# 안전       -0.191709 -0.191709 -0.191709 -0.210138  1.000000 -0.124581
# 환경        0.572262  0.572262  0.572262 -0.357841 -0.124581  1.000000
# 경제       -0.057815 -0.057815 -0.057815  0.071809 -0.142781 -0.716187
# 교육       -0.113522 -0.113522 -0.113522  0.242186 -0.519065 -0.146646
# 관계및사회참여   0.519122  0.519122  0.519122 -0.175048 -0.444827  0.169838
# 여가        0.497880  0.497880  0.497880 -0.405151  0.382730  0.494416
#
#                 경제        교육   관계및사회참여        여가
# 삶의 만족도_x -0.057815 -0.113522  0.519122  0.497880
# 삶의 만족도_y -0.057815 -0.113522  0.519122  0.497880
# 삶의 만족도   -0.057815 -0.113522  0.519122  0.497880
# 건강        0.071809  0.242186 -0.175048 -0.405151
# 안전       -0.142781 -0.519065 -0.444827  0.382730
# 환경       -0.716187 -0.146646  0.169838  0.494416
# 경제        1.000000  0.451395  0.298562 -0.367461
# 교육        0.451395  1.000000  0.462585 -0.070109
# 관계및사회참여   0.298562  0.462585  1.000000  0.216653
# 여가       -0.367461 -0.070109  0.216653  1.000000

# %%
plt.figure(figsize=(15, 6))
items = list(happy_merge.columns[1:9])
for a in items : 
    chatdata = happy_merge[a]
    plt.plot(chatdata, marker='o', label=a)

plt.xlabel('시도')
plt.ylabel('수치')
plt.xticks(range(17), happy_merge['시도'], fontsize=8)
plt.title('korea happiness index')
plt.legend()
plt.grid()
plt.show()

# %%
happy_merge.plot(kind='bar', xlabel='시도', ylabel='수치', figsize=(15, 20), grid=True, subplots=True)

plt.suptitle('대한민국 행복지수', fontsize=25)
plt.tight_layout(pad=8, h_pad=2)
plt.show()

# %%
plt.figure(figsize=(15, 13))
plt.title('대한민국 행복지수 상관관계', fontsize=25)

correlation_mat = happy_merge.corr()
upp_mat = triu(correlation_mat)

sns.heatmap(correlation_mat, mask=upp_mat, annot=True, cmap='RdYlGn')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 6
#       3 plt.figure(figsize=(15, 13))
#       4 plt.title('대한민국 행복지수 상관관계', fontsize=25)
# ----> 6 correlation_mat = happy_merge.corr()
#       7 upp_mat = triu(correlation_mat)
#       9 sns.heatmap(correlation_mat, mask=upp_mat, annot=True, cmap='RdYlGn')
#
# File c:\Users\jangy\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\jangy\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# File c:\Users\jangy\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py:1694, in BlockManager.as_array(self, dtype, copy, na_value)
#    1692         arr.flags.writeable = False
#    1693 else:
# -> 1694     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1695     # The underlying data was copied within _interleave, so no need
#    1696     # to further copy if copy=True or setting na_value
#    1698 if na_value is lib.no_default:
#
# File c:\Users\jangy\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py:1753, in BlockManager._interleave(self, dtype, na_value)
#    1751     else:
#    1752         arr = blk.get_values(dtype)
# -> 1753     result[rl.indexer] = arr
#    1754     itemmask[rl.indexer] = 1
#    1756 if not itemmask.all():
#
# ValueError: could not convert string to float: '서울특별시'
