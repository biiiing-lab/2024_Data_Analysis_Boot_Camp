# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
data = pd.read_excel('../file/health_screenings_2020_1000ea.xlsx')
data
# Out:
#      year  city_code  gender  age_code  height  weight  waist  eye_left  \
# 0    2020         36       1         9     165      60   72.1       1.2
# 1    2020         27       2        13     150      65   81.0       0.8
# 2    2020         11       2        12     155      55   70.0       0.6
# 3    2020         31       1        13     160      70   90.8       1.0
# 4    2020         41       2        12     155      50   75.2       1.5
# ..    ...        ...     ...       ...     ...     ...    ...       ...
# 995  2020         48       1        12     165      70   92.0       0.5
# 996  2020         41       1        12     165      70   88.0       1.2
# 997  2020         48       2        14     155      55   80.2       0.5
# 998  2020         41       2        14     150      55   79.5       1.0
# 999  2020         28       1        11     160      60   86.0       1.2
#
#      eye_right  hear_left  ...  serum   AST   ALT   GTP  smoking  drinking  \
# ...

# %%
data8 = data.loc[:, ['city_code', 'gender', 'waist']]

male_data = data8.loc[data8.gender==1, ['gender','waist']]
female_data = data8.loc[data8.gender==2, ['gender','waist']]

male = np.array(male_data['waist'], dtype=object)
female = np.array(female_data['waist'])

# %%
plt.figure(figsize=(10, 5))

# 답
plt.boxplot([male, female], labels=['male', 'female'])

plt.xlabel('gender')
plt.ylabel('waist')
plt.title('2020 health screenings male & female waist box plot')
plt.show()
# Out:
# C:\Users\jangy\AppData\Local\Temp\ipykernel_12956\196342200.py:4: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([male, female], labels=['male', 'female'])
